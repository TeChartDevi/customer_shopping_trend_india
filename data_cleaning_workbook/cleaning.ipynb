# %% [markdown]
# Importing library & loading dataset

# %%
import pandas as pd
import numpy as np
df= pd.read_csv("../raw_data/customer_shopping_behavior.csv")

# %%
print(f"Initial shape: {df.shape}")
# Out:
# Initial shape: (10000, 26)

# %% [markdown]
# Data Inspection

# %%
print(df.head(50))
# Out:
#    Transaction ID Customer ID Purchase Date  Age  Gender       Location  \
# 0       TXN507808  CUST102534    2023-01-01   51    Male        Chennai
# 1       TXN503830  CUST101256    2023-01-01   27  Female         Mumbai
# 2       TXN501496  CUST100490    2023-01-01   57    Male      Hyderabad
# 3       TXN501538  CUST100500    2023-01-01   22  Female           Pune
# 4       TXN504265  CUST101399    2023-01-01   30    Male  Visakhapatnam
# 5       TXN509250  CUST102952    2023-01-01   57    Male          Kochi
# 6       TXN501814  CUST100596    2023-01-01   42    Male      Hyderabad
# 7       TXN500031  CUST100007    2023-01-01   47    Male           Pune
# 8       TXN501550  CUST100505    2023-01-01   37  Female      Ahmedabad
# 9       TXN505122  CUST101684    2023-01-01   33    Male  Visakhapatnam
# 10      TXN501568  CUST100510    2023-01-01   59    Male        Chennai
# 11      TXN508080  CUST102612    2023-01-01   25    Male         Mumbai
# 12      TXN501212  CUST100365    2023-01-01   39    Male     Chandigarh
# 13      TXN500349  CUST100086    2023-01-02   22    Male         Mumbai
# 14      TXN504688  CUST101565    2023-01-02   37  Female      Hyderabad
# 15      TXN503278  CUST101052    2023-01-02   39  Female          Delhi
# 16      TXN507411  CUST102428    2023-01-02   49    Male      Bangalore
# 17      TXN502224  CUST100729    2023-01-02   45    Male         Indore
# 18      TXN505960  CUST101941    2023-01-02   28  Female        Chennai
# 19      TXN507732  CUST102512    2023-01-03   58  Female        Chennai
# 20      TXN509448  CUST103005    2023-01-03   33    Male         Jaipur
# 21      TXN505793  CUST101885    2023-01-03   25  Female      Hyderabad
# 22      TXN509881  CUST103157    2023-01-03   59  Female      Bangalore
# 23      TXN501497  CUST100490    2023-01-03   57    Male      Hyderabad
# 24      TXN508648  CUST102782    2023-01-03   49    Male         Mumbai
# 25      TXN507175  CUST102353    2023-01-03   37  Female           Pune
# 26      TXN507426  CUST102432    2023-01-03   24  Female      Bangalore
# 27      TXN502900  CUST100943    2023-01-03   37    Male          Kochi
# 28      TXN503760  CUST101229    2023-01-03   30  Female         Mumbai
# 29      TXN506726  CUST102209    2023-01-03   23  Female        Kolkata
# 30      TXN507997  CUST102593    2023-01-03   21  Female     Chandigarh
# 31      TXN502501  CUST100802    2023-01-04   39  Female          Kochi
# 32      TXN501236  CUST100379    2023-01-04   29    Male        Kolkata
# 33      TXN501598  CUST100517    2023-01-04   20    Male          Patna
# 34      TXN507126  CUST102338    2023-01-04   19    Male        Lucknow
# 35      TXN502409  CUST100773    2023-01-04   48    Male         Nagpur
# 36      TXN508997  CUST102876    2023-01-04   45  Female      Bangalore
# 37      TXN501732  CUST100566    2023-01-04   27  Female        Chennai
# 38      TXN500379  CUST100093    2023-01-04   34  Female      Bangalore
# 39      TXN500037  CUST100010    2023-01-04   40    Male        Kolkata
# 40      TXN501413  CUST100450    2023-01-05   58  Female        Kolkata
# 41      TXN505372  CUST101755    2023-01-05   31    Male        Chennai
# 42      TXN504345  CUST101435    2023-01-05   22  Female          Delhi
# 43      TXN508813  CUST102825    2023-01-05   53    Male          Delhi
# 44      TXN501364  CUST100432    2023-01-05   52    Male        Chennai
# 45      TXN501186  CUST100355    2023-01-05   59  Female          Delhi
# 46      TXN505208  CUST101713    2023-01-05   48  Female          Noida
# 47      TXN508189  CUST102642    2023-01-05   26    Male        Lucknow
# 48      TXN500001  CUST100001    2023-01-05   50    Male      Bangalore
# 49      TXN505866  CUST101915    2023-01-06   39  Female          Surat
#
#    Online/Offline Online Store     Category Item Purchased  ... Festival/Sale  \
# 0          Online     Flipkart     Clothing          Kurta  ...           NaN
# 1         Offline          NaN     Clothing          Shirt  ...           NaN
# 2          Online     Flipkart     Clothing         Jacket  ...           NaN
# 3          Online       Myntra     Clothing          Kurta  ...           NaN
# 4          Online       Myntra  Accessories            Cap  ...           NaN
# 5         Offline          NaN  Accessories          Watch  ...           NaN
# 6          Online       Myntra     Footwear   Formal Shoes  ...           NaN
# 7          Online       Myntra     Clothing         Jacket  ...           NaN
# 8         Offline          NaN     Clothing          Saree  ...           NaN
# 9          Online       Amazon     Clothing         Hoodie  ...           NaN
# 10         Online         Ajio     Clothing         Jacket  ...           NaN
# 11         Online     Flipkart     Footwear          Boots  ...           NaN
# 12         Online       Amazon     Footwear        Sandals  ...           NaN
# 13         Online        Shein     Clothing        T-shirt  ...           NaN
# 14         Online       Myntra     Clothing          Kurta  ...           NaN
# 15         Online       Myntra     Clothing          Kurta  ...           NaN
# 16         Online       Meesho     Footwear          Boots  ...           NaN
# 17         Online     Flipkart     Clothing       Trousers  ...           NaN
# 18         Online       Myntra     Footwear       Slippers  ...           NaN
# 19        Offline          NaN     Clothing         Jacket  ...           NaN
# 20         Online         Ajio     Clothing         Hoodie  ...           NaN
# 21         Online     Flipkart     Clothing          Dress  ...           NaN
# 22         Online       Amazon     Clothing          Kurta  ...           NaN
# 23         Online       Meesho     Footwear       Slippers  ...           NaN
# 24         Online     Flipkart  Accessories          Socks  ...           NaN
# 25         Online       Myntra     Footwear       Sneakers  ...           NaN
# 26        Offline          NaN     Footwear  Running Shoes  ...           NaN
# 27        Offline          NaN     Clothing         Shorts  ...           NaN
# 28        Offline          NaN     Clothing         Hoodie  ...           NaN
# 29         Online       Myntra     Clothing       Trousers  ...           NaN
# 30        Offline          NaN     Footwear   Formal Shoes  ...           NaN
# 31        Offline          NaN     Footwear        Sandals  ...           NaN
# 32         Online       Amazon     Clothing          Shirt  ...           NaN
# 33         Online         Ajio  Accessories          Watch  ...           NaN
# 34         Online        Shein  Accessories     Sunglasses  ...           NaN
# 35         Online       Myntra     Clothing         Jacket  ...           NaN
# 36         Online       Myntra  Accessories       Backpack  ...           NaN
# 37        Offline          NaN     Clothing          Dress  ...           NaN
# 38         Online       Myntra     Footwear       Sneakers  ...           NaN
# 39         Online       Amazon     Clothing         Jacket  ...           NaN
# 40         Online     Flipkart     Footwear   Formal Shoes  ...           NaN
# 41         Online     Flipkart     Clothing         Jacket  ...           NaN
# 42         Online     Flipkart  Accessories            Cap  ...           NaN
# 43         Online        Shein     Clothing         Hoodie  ...           NaN
# 44         Online       Amazon  Accessories         Wallet  ...           NaN
# 45         Online       Amazon     Clothing          Dress  ...           NaN
# 46         Online       Myntra     Clothing          Dress  ...           NaN
# 47         Online     Flipkart  Accessories         Wallet  ...           NaN
# 48         Online       Meesho     Clothing       Trousers  ...           NaN
# 49        Offline          NaN     Clothing         Hoodie  ...           NaN
#
#    Shipping Charge (₹) Delivery Speed  Delivery Time (Days)  \
# 0                    0       Same Day                     1
# 1                    0            NaN                     0
# 2                    0       Standard                     7
# 3                    0       Standard                     6
# 4                   99        Express                     2
# 5                    0            NaN                     0
# 6                    0       Standard                     4
# 7                    0       Standard                     5
# 8                    0            NaN                     0
# 9                   49       Standard                     4
# 10                   0       Standard                     8
# 11                  99        Express                     4
# 12                   0       Standard                     8
# 13                  99       Standard                     4
# 14                   0       Standard                     8
# 15                   0       Standard                     5
# 16                  49       Standard                     6
# 17                  79        Express                     4
# 18                   0       Standard                     6
# 19                   0            NaN                     0
# 20                   0       Standard                     5
# 21                  49        Express                     3
# 22                   0       Standard                     5
# 23                  79        Express                     3
# 24                   0       Standard                     6
# 25                 199        Express                     3
# 26                   0            NaN                     0
# 27                   0            NaN                     0
# 28                   0            NaN                     0
# 29                   0       Standard                     7
# 30                   0            NaN                     0
# 31                   0            NaN                     0
# 32                  79       Standard                     8
# 33                   0       Standard                     6
# 34                   0       Standard                     6
# 35                  99       Standard                     8
# 36                   0        Express                     3
# 37                   0            NaN                     0
# 38                  99       Standard                     5
# 39                  79       Standard                     5
# 40                  79        Express                     4
# 41                  79       Standard                     5
# 42                   0       Standard                     5
# 43                  99       Standard                     5
# 44                   0        Express                     2
# 45                  49       Standard                     8
# 46                 199        Express                     2
# 47                   0       Standard                     4
# 48                   0        Express                     2
# 49                   0            NaN                     0
#
#     Subscription Status    Payment Method Review Rating  Return Status  \
# 0                   Yes  Cash on Delivery             4   Not Returned
# 1                    No               UPI             5   Not Returned
# 2                   Yes               UPI             3   Not Returned
# 3                   Yes       Net Banking             4   Not Returned
# 4                    No        Debit Card             4   Not Returned
# 5                    No       Credit Card             5   Not Returned
# 6                    No               UPI             3   Not Returned
# 7                    No       Credit Card             5   Not Returned
# 8                   Yes               UPI             5       Returned
# 9                   Yes  Cash on Delivery             5       Returned
# 10                  Yes               UPI             3   Not Returned
# 11                   No  Cash on Delivery             3   Not Returned
# 12                   No       Credit Card             3   Not Returned
# 13                   No               UPI             5       Returned
# 14                   No       Credit Card             3   Not Returned
# 15                   No        Debit Card             5   Not Returned
# 16                   No       Credit Card             3   Not Returned
# 17                   No       Credit Card             4   Not Returned
# 18                  Yes               UPI             4   Not Returned
# 19                  Yes               UPI             5       Returned
# 20                  Yes       Credit Card             5   Not Returned
# 21                   No  Cash on Delivery             5   Not Returned
# 22                   No               UPI             4   Not Returned
# 23                  Yes               UPI             3   Not Returned
# 24                  Yes       Credit Card             5   Not Returned
# 25                   No       Credit Card             5   Not Returned
# 26                  Yes        Debit Card             5       Returned
# 27                   No               UPI             4   Not Returned
# 28                   No       Credit Card             3   Not Returned
# 29                   No               UPI             4   Not Returned
# 30                   No               UPI             4   Not Returned
# 31                  Yes               UPI             4       Returned
# 32                   No       Credit Card             4   Not Returned
# 33                  Yes               UPI             3   Not Returned
# 34                  Yes               UPI             3       Returned
# 35                   No  Cash on Delivery             3   Not Returned
# 36                  Yes       Credit Card             3   Not Returned
# 37                   No               UPI             4   Not Returned
# 38                   No               UPI             4   Not Returned
# 39                   No            Wallet             5   Not Returned
# 40                   No               UPI             3   Not Returned
# 41                   No               UPI             4   Not Returned
# 42                   No               UPI             5   Not Returned
# 43                   No  Cash on Delivery             4   Not Returned
# 44                   No               UPI             4   Not Returned
# 45                   No            Wallet             4   Not Returned
# 46                   No        Debit Card             5   Not Returned
# 47                   No               UPI             3   Not Returned
# 48                   No               EMI             3   Not Returned
# 49                  Yes  Cash on Delivery             3       Returned
#
#    Previous Purchases  Frequency of Purchases
# 0                   0             Fortnightly
# 1                   0             Fortnightly
# 2                   0                  Rarely
# 3                   0             Fortnightly
# 4                   0                  Weekly
# 5                   0             Fortnightly
# 6                   0                 Monthly
# 7                   0                 Monthly
# 8                   0             Fortnightly
# 9                   0                  Weekly
# 10                  0                  Weekly
# 11                  0             Fortnightly
# 12                  0             Fortnightly
# 13                  0                  Weekly
# 14                  0               Quarterly
# 15                  0             Fortnightly
# 16                  0                  Weekly
# 17                  0                 Monthly
# 18                  0                  Weekly
# 19                  0             Fortnightly
# 20                  0                 Monthly
# 21                  0             Fortnightly
# 22                  0                  Weekly
# 23                  1                  Rarely
# 24                  0             Fortnightly
# 25                  0             Fortnightly
# 26                  0             Fortnightly
# 27                  0                  Weekly
# 28                  0                 Monthly
# 29                  0                  Weekly
# 30                  0                  Weekly
# 31                  0                 Monthly
# 32                  0                  Weekly
# 33                  0                  Weekly
# 34                  0             Fortnightly
# 35                  0                 Monthly
# 36                  0                  Rarely
# 37                  0                  Weekly
# 38                  0                  Weekly
# 39                  0             Fortnightly
# 40                  0                 Monthly
# 41                  0                 Monthly
# 42                  0             Fortnightly
# 43                  0             Fortnightly
# 44                  0                  Rarely
# 45                  0                 Monthly
# 46                  0             Fortnightly
# 47                  0                  Rarely
# 48                  0                  Weekly
# 49                  0             Fortnightly
#
# [50 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Transaction ID          10000 non-null  object
#  1   Customer ID             10000 non-null  object
#  2   Purchase Date           10000 non-null  object
#  3   Age                     10000 non-null  int64
#  4   Gender                  10000 non-null  object
#  5   Location                10000 non-null  object
#  6   Online/Offline          10000 non-null  object
#  7   Online Store            7751 non-null   object
#  8   Category                10000 non-null  object
#  9   Item Purchased          10000 non-null  object
#  10  Brand                   10000 non-null  object
#  11  Color                   10000 non-null  object
#  12  Size                    8965 non-null   object
#  13  Quantity                10000 non-null  int64
#  14  Purchase Amount (₹)     10000 non-null  int64
#  15  Discount (%)            10000 non-null  int64
#  16  Festival/Sale           3212 non-null   object
#  17  Shipping Charge (₹)     10000 non-null  int64
#  18  Delivery Speed          7751 non-null   object
#  19  Delivery Time (Days)    10000 non-null  int64
#  20  Subscription Status     10000 non-null  object
#  21  Payment Method          10000 non-null  object
#  22  Review Rating           10000 non-null  int64
#  23  Return Status           10000 non-null  object
#  24  Previous Purchases      10000 non-null  int64
#  25  Frequency of Purchases  10000 non-null  object
# dtypes: int64(8), object(18)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#                 Age      Quantity  Purchase Amount (₹)  Discount (%)  \
# count  10000.000000  10000.000000         10000.000000  10000.000000
# mean      38.278100      1.425100          1889.882000     32.916300
# std       12.133041      0.761346          2102.301836     21.440617
# min       18.000000      1.000000            67.000000      0.000000
# 25%       28.000000      1.000000           600.000000     12.000000
# 50%       38.000000      1.000000          1207.000000     33.000000
# 75%       49.000000      2.000000          2376.000000     52.000000
# max       59.000000      4.000000         22306.000000     70.000000
#
#        Shipping Charge (₹)  Delivery Time (Days)  Review Rating  \
# count          10000.00000          10000.000000   10000.000000
# mean              41.49210              3.703600       3.874900
# std               64.30923              2.726223       0.912871
# min                0.00000              0.000000       1.000000
# 25%                0.00000              1.000000       3.000000
# 50%                0.00000              4.000000       4.000000
# 75%               79.00000              6.000000       5.000000
# max              199.00000              8.000000       5.000000
#
#        Previous Purchases
# count        10000.000000
# mean             3.211400
# std              3.951313
# min              0.000000
# 25%              0.000000
# 50%              2.000000
# 75%              4.000000
# max             28.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Note:
#     - Duplicates Not Found.

# %% [markdown]
# #### Data to Clean:
# - 1. Null Value Check and Handling.
# - 2. Renaming Location column to Cities column.
# - 3. Convert Purchase Date to relevant Dtype.

# %% [markdown]
# ### 1. Null Value Check and Handling.

# %%
# Null Value Check:
df.isnull().sum().sort_values(ascending=False)
# Out:
# Festival/Sale             6788
# Online Store              2249
# Delivery Speed            2249
# Size                      1035
# Transaction ID               0
# Purchase Amount (₹)          0
# Previous Purchases           0
# Return Status                0
# Review Rating                0
# Payment Method               0
# Subscription Status          0
# Delivery Time (Days)         0
# Shipping Charge (₹)          0
# Discount (%)                 0
# Quantity                     0
# Customer ID                  0
# Color                        0
# Brand                        0
# Item Purchased               0
# Category                     0
# Online/Offline               0
# Location                     0
# Gender                       0
# Age                          0
# Purchase Date                0
# Frequency of Purchases       0
# dtype: int64

# %% [markdown]
# Note:
# - Found nulls in Column:
#     - A. Festival/Sale             6788
#     - B. Online Store              2249
#     - C. Delivery Speed            2249
#     - D. Size                      1035

# %% [markdown]
# ##### A. Null Value Handling for Column Festival/Sale

# %%
# 1. Column Unique Val check:
df['Festival/Sale'].unique()
# Out:
# array([nan, 'Republic Day Sale', 'Holi Sale', 'Amazon Great Summer Sale',
#        'Independence Day Sale', 'Big Billion Days', 'Diwali Sale',
#        'End of Season Sale'], dtype=object)

# %%
# 2. Null Val cross-relation check between 'Festival/Sale','Online Store':

df[df[['Festival/Sale','Online Store']].isnull().any(axis=1)][['Festival/Sale','Online Store']]
# Out:
#            Festival/Sale Online Store
# 0                    NaN     Flipkart
# 1                    NaN          NaN
# 2                    NaN     Flipkart
# 3                    NaN       Myntra
# 4                    NaN       Myntra
# ...                  ...          ...
# 9987  End of Season Sale          NaN
# 9989  End of Season Sale          NaN
# 9991  End of Season Sale          NaN
# 9992  End of Season Sale          NaN
# 9994  End of Season Sale          NaN
#
# [7491 rows x 2 columns]

# %%
# 3. Null Value Handling:

df['Festival/Sale'] = df['Festival/Sale'].fillna('Regular Day')

# %%
# 4. Verifing Null Value Replacement:

print(df['Festival/Sale'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### B. Null Value Handling for Column Online Store:

# %%
# 1. Null Value Handling:

df.loc[
    (df['Online/Offline'] == 'Offline') & 
    (df['Online Store'].isna()),
    'Online Store'
] = 'In-Store Purchase'

# -- Note: Where the Online/Offline was 'Offline' &  the Online Store was missing, I replaced the missing Online Store with "In-Store Purchase"

# %%
# 2. Verifing Null Value Replacement:

df[['Online/Offline', 'Online Store']].head(10)
# Out:
#   Online/Offline       Online Store
# 0         Online           Flipkart
# 1        Offline  In-Store Purchase
# 2         Online           Flipkart
# 3         Online             Myntra
# 4         Online             Myntra
# 5        Offline  In-Store Purchase
# 6         Online             Myntra
# 7         Online             Myntra
# 8        Offline  In-Store Purchase
# 9         Online             Amazon

# %% [markdown]
# ##### C. Null Value Handling for Column Delivery Speed

# %%
# C(1). Null Value Handling:
df.loc[
    (df['Delivery Time (Days)'] == 0) & 
    (df['Delivery Speed'].isna()), 
    'Delivery Speed'
] = 'N/A (Offline)'

## Note: Where the delivery time was 0 days &  the Delivery Speed was missing, I replaced the missing Delivery Speed with "N/A (Offline)"

# %%
# C(2). Verifing Null Value Replacement:

print(df['Delivery Speed'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### D. Null Value Handling for Column Size

# %%
# 1. Column Unique Val check:
df.loc[df['Size'].isna(), 'Category'].unique()
# Out:
# array(['Accessories'], dtype=object)

# %% [markdown]
# Note:
# - All Null values are from the same category.

# %%
# 2. Null Val cross-relation check between Category, Item Purchased & Size:

df[df[['Category', 'Item Purchased','Size']].isnull().any(axis=1)][['Category', 'Item Purchased', 'Size']]
# Out:
#          Category Item Purchased Size
# 5     Accessories          Watch  NaN
# 33    Accessories          Watch  NaN
# 34    Accessories     Sunglasses  NaN
# 44    Accessories         Wallet  NaN
# 47    Accessories         Wallet  NaN
# ...           ...            ...  ...
# 9935  Accessories           Belt  NaN
# 9954  Accessories          Watch  NaN
# 9974  Accessories          Watch  NaN
# 9988  Accessories     Sunglasses  NaN
# 9991  Accessories           Belt  NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# Note:
# - No specific sub-category relation found for the nulls.
# - Thus, filling up with Unknown

# %%
# 3. Null value handling:

df['Size'] = df['Size'].fillna('Unknown')

# %%
# 4.  Verifying Null Value Replacement:

print(df['Size'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### B. Renaming the Location column with Cities column.

# %%
df.rename(columns={'Location': 'Cities'}, inplace=True)

# %% [markdown]
# ##### C. Convert Purchase Date to relevant Dtype

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'], errors = 'coerce')

print(df['Purchase Date'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# # Feature Engineering:
# - A. Creating a New Region Column.
# - B. Creating column for footwear and clothing size.
# - C. Extracting Parts of date.
# - D. Creating Age group

# %% [markdown]
# ##### A. Creating a New Region Column:

# %%
# 1. All unique city names:

df['Cities'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Hyderabad', 'Pune', 'Visakhapatnam', 'Kochi',
#        'Ahmedabad', 'Chandigarh', 'Delhi', 'Bangalore', 'Indore',
#        'Jaipur', 'Kolkata', 'Patna', 'Lucknow', 'Nagpur', 'Noida',
#        'Surat', 'Bhubaneswar', 'Gurgaon'], dtype=object)

# %%
# 2. Mapping the cities

region_map = {
    'Delhi': 'North',
    'Noida': 'North',
    'Gurgaon': 'North',
    'Chandigarh': 'North',
    'Jaipur': 'North',
    'Lucknow': 'North',

    'Chennai': 'South',
    'Hyderabad': 'South',
    'Visakhapatnam': 'South',
    'Kochi': 'South',
    'Bangalore': 'South',

    'Mumbai': 'West',
    'Pune': 'West',
    'Ahmedabad': 'West',
    'Nagpur': 'West',
    'Surat': 'West',

    'Kolkata': 'East',
    'Patna': 'East',
    'Bhubaneswar': 'East',

    'Indore': 'Central'
}

df['Region'] = df['Cities'].map(region_map)

# %%
# 3. Popping out the region column:

region = df.pop('Region')

# Finding the position of the Cities column:

city_loc = df.columns.get_loc('Cities')

# Inserting Region column immediately after Cities column:

df.insert(city_loc + 1, 'Region', region)

# %% [markdown]
# ##### B. Creating column for Footwear & Clothing Size.

# %%
# 1. Category column unique vals:
df['Category'].unique()
# Out:
# array(['Clothing', 'Accessories', 'Footwear'], dtype=object)

# %%
# 2. Footwear Size:
df['Footwear_Size'] = np.where(df['Category'] == 'Footwear', df['Size'], 'Not Applicable')

# 3. Clothing Size:
df['Clothing_Size'] = np.where(df['Category'] != 'Footwear', df['Size'], 'Not Applicable')

# %%
# 4. Finding the position of the Size column:

size_loc = df.columns.get_loc('Size')

# 5. Inserting Clothing_Size column immediately after Size column:

df.insert(size_loc + 1, 'Clothing_Size', Clothing_Size)

# 6. Inserting Footwear_Size column immediately after Size column:

df.insert(size_loc + 2, 'Footwear_Size', Footwear_Size)

# %%
# 7. Dropping Size column:
df.drop( columns = ['Size'], inplace = True)

# %%
# 8. Column after changes:
df[['Category', 'Footwear_Size', 'Clothing_Size']].head(10)
# Out:
#       Category   Footwear_Size   Clothing_Size
# 0     Clothing  Not Applicable               M
# 1     Clothing  Not Applicable               L
# 2     Clothing  Not Applicable             XXL
# 3     Clothing  Not Applicable              XS
# 4  Accessories  Not Applicable       Free Size
# 5  Accessories  Not Applicable         Unknown
# 6     Footwear              10  Not Applicable
# 7     Clothing  Not Applicable               S
# 8     Clothing  Not Applicable               M
# 9     Clothing  Not Applicable              XS

# %% [markdown]
# ##### C. Extracting Parts of Date

# %%
# 1. Finding the position of the Purchase Date column:
purchase_date_loc = df.columns.get_loc('Purchase Date')


# 2. Extracting Year and inserting it immediately after the Purchase Date column:
df.insert(purchase_date_loc + 1, 'Year', df['Purchase Date'].dt.year)


# 3. Extracting Month and inserting it immediately after the Year column:
df.insert(purchase_date_loc + 2, 'Month', df['Purchase Date'].dt.month)


# 4. Extracting Day and inserting it immediately after the Month column:
df.insert(purchase_date_loc + 3, 'Day', df['Purchase Date'].dt.day)


# 5. Extracting Weekday Name and inserting it immediately after the Day column:
df.insert(purchase_date_loc + 4, 'Weekday', df['Purchase Date'].dt.day_name())

# %% [markdown]
# D. Creating Age group:

# %%
def age_group(age):
    if age < 18:
        return 'Under 18'
    elif age <= 25:
        return '18-25'
    elif age <= 35:
        return '26-35'
    elif age <= 45:
        return '36-45'
    elif age <= 60:
        return '46-60'
    else:
        return 'Above 60'
    
# Finding the position of the age column:
age_loc = df.columns.get_loc('Age')

# Inserting the Age Group column immediately after the age column:
df.insert(age_loc + 1, 'Age Group', df['Age'].apply(age_group))

# %%
df.head()
# Out:
#   Transaction ID Customer ID Purchase Date  Year  Month  Day Weekday  Age  \
# 0      TXN507808  CUST102534    2023-01-01  2023      1    1  Sunday   51
# 1      TXN503830  CUST101256    2023-01-01  2023      1    1  Sunday   27
# 2      TXN501496  CUST100490    2023-01-01  2023      1    1  Sunday   57
# 3      TXN501538  CUST100500    2023-01-01  2023      1    1  Sunday   22
# 4      TXN504265  CUST101399    2023-01-01  2023      1    1  Sunday   30
#
#   Age Group  Gender  ... Delivery Speed Delivery Time (Days)  \
# 0     46-60    Male  ...       Same Day                    1
# 1     26-35  Female  ...  N/A (Offline)                    0
# 2     46-60    Male  ...       Standard                    7
# 3     18-25  Female  ...       Standard                    6
# 4     26-35    Male  ...        Express                    2
#
#   Subscription Status    Payment Method Review Rating Return Status  \
# 0                 Yes  Cash on Delivery             4  Not Returned
# 1                  No               UPI             5  Not Returned
# 2                 Yes               UPI             3  Not Returned
# 3                 Yes       Net Banking             4  Not Returned
# 4                  No        Debit Card             4  Not Returned
#
#   Previous Purchases Frequency of Purchases   Footwear_Size  Clothing_Size
# 0                  0            Fortnightly  Not Applicable              M
# 1                  0            Fortnightly  Not Applicable              L
# 2                  0                 Rarely  Not Applicable            XXL
# 3                  0            Fortnightly  Not Applicable             XS
# 4                  0                 Weekly  Not Applicable      Free Size
#
# [5 rows x 33 columns]

# %%
print(f"Shape After Preprocessing:", {df.shape})
# Out:
# Shape After Preprocessing: {(10000, 33)}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Transaction ID          10000 non-null  object
#  1   Customer ID             10000 non-null  object
#  2   Purchase Date           10000 non-null  datetime64[ns]
#  3   Year                    10000 non-null  int32
#  4   Month                   10000 non-null  int32
#  5   Day                     10000 non-null  int32
#  6   Weekday                 10000 non-null  object
#  7   Age                     10000 non-null  int64
#  8   Age Group               10000 non-null  object
#  9   Gender                  10000 non-null  object
#  10  Cities                  10000 non-null  object
#  11  Region                  10000 non-null  object
#  12  Online/Offline          10000 non-null  object
#  13  Online Store            10000 non-null  object
#  14  Category                10000 non-null  object
#  15  Item Purchased          10000 non-null  object
#  16  Brand                   10000 non-null  object
#  17  Color                   10000 non-null  object
#  18  Quantity                10000 non-null  int64
#  19  Purchase Amount (₹)     10000 non-null  int64
#  20  Discount (%)            10000 non-null  int64
#  21  Festival/Sale           10000 non-null  object
#  22  Shipping Charge (₹)     10000 non-null  int64
#  23  Delivery Speed          10000 non-null  object
#  24  Delivery Time (Days)    10000 non-null  int64
#  25  Subscription Status     10000 non-null  object
#  26  Payment Method          10000 non-null  object
#  27  Review Rating           10000 non-null  int64
#  28  Return Status           10000 non-null  object
#  29  Previous Purchases      10000 non-null  int64
#  30  Frequency of Purchases  10000 non-null  object
#  31  Footwear_Size           10000 non-null  object
#  32  Clothing_Size           10000 non-null  object
# dtypes: datetime64[ns](1), int32(3), int64(8), object(21)
# memory usage: 2.4+ MB

# %% [markdown]
# Exporting Clean Dataset

# %%
df.to_csv("../clean_data/clean_customer_shopping_behavior_india.csv", index=False)

# %% [markdown]
# ## Conclusion
#
# - Performed an initial dataset inspection of the dataset using `.info()` and `.describe()`.
#
# - Conducted duplicate record analysis.
#
# - Identified a datatype inconsistency in the `Purchase Date` column.
#
# - Renamed `Location` column to `Cities` to improve dataframe readablity.
#
# - Identified and handled missing values in the following columns:
#   - `Festival/Sale`
#   - `Online Store`
#   - `Delivery Speed`
#   - `Size`
#
# - Corrected datatype inconsistencies by converting the `Purchase Date` column from `object` to `datetime`.
#
# - Engineered new business-relevant features, including:
#   - Created a `Region` column immedietly after `Cities` using a mapping funtion.
#   - Created a `Footwear_Size` & `Clothing_Size` column immedietly after `Size` then dropped the `Size` column.
#   - Extracted `Year`, `Month`, `Day` and `Weekday` from the `Purchase Date` column and inserted them immedietly after it.
#   - Created a `Age Group` column immedietly after `Age` using a user-defined (`def`) funtion
#
# - Verified the dataset's shape and confirmed successful handling of missing values after preprocessing.
#
# - Exported the cleaned dataset for further analysis.
